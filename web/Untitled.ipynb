# %%
import requests

# %%
import requests
from bs4 import BeautifulSoup
 
if __name__ == "__main__":
    RANK = 100 ## 멜론 차트 순위가 1 ~ 100위까지 있음
 
    header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}
    req = requests.get('https://www.melon.com/chart/week/index.htm', headers = header) ## 주간 차트를 크롤링 할 것임
    html = req.text
    parse = BeautifulSoup(html, 'html.parser')
 
    titles = parse.find_all("div", {"class": "ellipsis rank01"}) 
    singers = parse.find_all("div", {"class": "ellipsis rank02"}) 
    albums = parse.find_all("div",{"class": "ellipsis rank03"})
 
    title = []
    singer = []
    album = []
 
    for t in titles:
        title.append(t.find('a').text)
 
    for s in singers:
        singer.append(s.find('span', {"class": "checkEllipsis"}).text)

    for a in albums:
        album.append(a.find('a').text)
 
    for i in range(RANK):
        print('%3d위: %s [ %s ] - %s'%(i+1, title[i], album[i], singer[i]))
# Out:
#   1위: 사랑하게 될 줄 알았어 [ 슬기로운 의사생활 OST Part 11 ] - 전미도
#   2위: 에잇(Prod.&Feat. SUGA of BTS) [ 에잇 ] - 아이유
#   3위: 아로하 [ 슬기로운 의사생활 OST Part 3 ] - 조정석
#   4위: MORE & MORE [ MORE & MORE ] - TWICE (트와이스)
#   5위: 살짝 설렜어 (Nonstop) [ NONSTOP ] - 오마이걸
#   6위: 깡 Official Remix [ 깡 Official Remix ] - 식케이 (Sik-K), pH-1, 박재범, 김하온 (HAON)
#   7위: 나비와 고양이 (feat.백현 (BAEKHYUN)) [ 사춘기집Ⅱ 꽃 본 나비 ] - 볼빨간사춘기
#   8위: 좋은 사람 있으면 소개시켜줘 [ 슬기로운 의사생활 OST Part 2 ] - 조이 (JOY)
#   9위: 너에게 난, 나에게 넌 [ 슬기로운 의사생활 OST Part 12 ] - 미도와 파라솔
#  10위: 화려하지 않은 고백 [ 슬기로운 의사생활 OST Part 4 ] - 규현 (KYUHYUN)
#  11위: 시작 [ 이태원 클라쓰 OST Part.2 ] - 가호 (Gaho)
#  12위: 처음처럼 [ CEREMONIA ] - 엠씨더맥스 (M.C the MAX)
#  13위: 그대 고운 내사랑 [ 슬기로운 의사생활 OST Part 5 ] - 어반자카파
#  14위: 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야 [ 멜로가 체질 OST Part 3 ] - 장범준
#  15위: 아무노래 [ 아무노래 ] - 지코 (ZICO)
#  16위: Dolphin [ NONSTOP ] - 오마이걸
#  17위: Candy [ Delight - The 2nd Mini Album ] - 백현 (BAEKHYUN)
#  18위: 덤더럼(Dumhdurum) [ LOOK ] - Apink (에이핑크)
#  19위: Dance Monkey [ The Kids Are Coming ] - Tones And I
#  20위: ON [ MAP OF THE SOUL : 7 ] - 방탄소년단
#  21위: METEOR [ Boyhood ] - 창모 (CHANGMO)
#  22위: Blueming [ Love poem ] - 아이유
#  23위: 내 눈물 모아 [ 슬기로운 의사생활 OST Part 8 ] - 휘인 (Whee In)
#  24위: Memories [ Memories ] - Maroon 5
#  25위: 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey) [ MAP OF THE SOUL : PERSONA ] - 방탄소년단
#  26위: Don't Start Now [ Future Nostalgia ] - Dua Lipa
#  27위: 마음을 드려요 [ 사랑의 불시착 OST Part 11 ] - 아이유
#  28위: 그때 그 아인 [ 이태원 클라쓰 OST Part.6 ] - 김필
#  29위: 돌덩이 [ 이태원 클라쓰 OST Part.3 ] - 하현우 (국카스텐)
#  30위: 어떻게 지내 (Prod. By VAN.C) [ 어떻게 지내 ] - 오반
#  31위: 늦은 밤 너의 집 앞 골목길에서 [ 늦은 밤 너의 집 앞 골목길에서 ] - 노을
#  32위: 너를 사랑하고 있어 [ 낭만닥터 김사부 2 OST Part.1 ] - 백현 (BAEKHYUN)
#  33위: Happy [ Happy ] - 태연 (TAEYEON)
#  34위: 2002 [ Speak Your Mind (Deluxe) ] - Anne-Marie
#  35위: Psycho [ ‘The ReVe Festival’ Finale ] - Red Velvet (레드벨벳)
#  36위: WANNABE [ IT'z ME ] - ITZY (있지)
#  37위: 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온) [ Red Moon : To You My Light ] - 마크툽 (MAKTUB)
#  38위: 반만 [ 반만 ] - 진민호
#  39위: 깡 [ MY LIFE愛 ] - 비
#  40위: 이제 나만 믿어요 [ 내일은 미스터트롯 우승자 특전곡 ] - 임영웅
#  41위: 우리 만남이 [ 정규 2집 '마음, 둘' ] - 폴킴
#  42위: 취했나봐 [ 취했나봐 ] - 황인욱
#  43위: 모든 날, 모든 순간 (Every day, Every Moment) [ `키스 먼저 할까요?` OST Part.3 ] - 폴킴
#  44위: Lonely Night [ 슬기로운 의사생활 OST Part 1 ] - 권진아
#  45위: Maniac [ Maniac ] - Conan Gray
#  46위: 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 [ 항해 ] - AKMU (악동뮤지션)
#  47위: 00:00 (Zero O’Clock) [ MAP OF THE SOUL : 7 ] - 방탄소년단
#  48위: 우리 왜 헤어져야 해 [ 우리 왜 헤어져야 해 ] - 신예영
#  49위: 밤이 깊었네 (Drama Ver.) [ 슬기로운 의사생활 OST Part 10 ] - 미도와 파라솔
#  50위: Black Swan [ MAP OF THE SOUL : 7 ] - 방탄소년단
#  51위: FIESTA [ BLOOM*IZ ] - IZ*ONE (아이즈원)
#  52위: 안녕 [ 호텔 델루나 OST Part.10 ] - 폴킴
#  53위: 품 [ 사춘기집Ⅱ 꽃 본 나비 ] - 볼빨간사춘기
#  54위: Love poem [ Love poem ] - 아이유
#  55위: Stuck with U [ Stuck with U ] - Ariana Grande, Justin Bieber
#  56위: 자나깨나 (Feat. 조이 of Red Velvet) [ homemade 1 ] - Crush
#  57위: 찐이야 [ 내일은 미스터트롯 결승전 베스트 ] - 영탁
#  58위: 친구 [ MAP OF THE SOUL : 7 ] - 방탄소년단
#  59위: HIP [ reality in BLACK ] - 마마무 (Mamamoo)
#  60위: Paris In The Rain [ I met you when I was 18. (the playlist) ] - Lauv
#  61위: Bungee [ Delight - The 2nd Mini Album ] - 백현 (BAEKHYUN)
#  62위: 너를 그린 우주 (Insomnia2020) (Feat. 이라온) [ Red Moon : SUPERNOVA ] - 마크툽 (MAKTUB)
#  63위: Stay Tonight [ Stay Tonight ] - 청하
#  64위: bad guy [ WHEN WE ALL FALL ASLEEP, WHERE DO WE GO? ] - Billie Eilish
#  65위: To Die For [ To Die For ] - Sam Smith
#  66위: 너에게 가는 이 길 위에서 (너.이.길) [ 하이에나 OST Part.2 ] - 백현 (BAEKHYUN)
#  67위: Filter [ MAP OF THE SOUL : 7 ] - 방탄소년단
#  68위: Love Again [ Delight - The 2nd Mini Album ] - 백현 (BAEKHYUN)
#  69위: 어느 60대 노부부이야기 [ 내일은 미스터트롯 트롯 에이드 베스트 ] - 임영웅
#  70위: Moon [ MAP OF THE SOUL : 7 ] - 방탄소년단
#  71위: 봄날 [ YOU NEVER WALK ALONE ] - 방탄소년단
#  72위: 시차 [ MAP OF THE SOUL : 7 ] - 방탄소년단
#  73위: Painkiller [ Painkiller ] - Ruel
#  74위: 시청 앞 지하철 역에서 [ 슬기로운 의사생활 OST Part 6 ] - 곽진언
#  75위: Inner Child [ MAP OF THE SOUL : 7 ] - 방탄소년단
#  76위: We are Bulletproof : the Eternal [ MAP OF THE SOUL : 7 ] - 방탄소년단
#  77위: 12:45 (Stripped) [ 12:45 (Stripped) ] - Etham
#  78위: 살아가는 거야 [ 살아가는 거야 ] - 로이킴
#  79위: 바램 [ 내일은 미스터트롯 예선곡 베스트 ] - 임영웅
#  80위: 넌 언제나 [ 슬기로운 의사생활 OST Part 7 ] - 제이레빗(J Rabbit)
#  81위: 너를 만나 [ 너를 만나 ] - 폴킴
#  82위: 시든 꽃에 물을 주듯 [ 시든 꽃에 물을 주듯 ] - HYNN (박혜원)
#  83위: 조금 취했어 (Prod. 2soo) [ 조금 취했어 ] - 임재현
#  84위: Louder than bombs [ MAP OF THE SOUL : 7 ] - 방탄소년단
#  85위: Poppin' [ Delight - The 2nd Mini Album ] - 백현 (BAEKHYUN)
#  86위: Obsession [ OBSESSION - The 6th Album ] - EXO
#  87위: 사랑이란 멜로는 없어 [ 사랑이란 멜로는 없어 ] - 전상근
#  88위: 욱 (UGH!) [ MAP OF THE SOUL : 7 ] - 방탄소년단
#  89위: 다시 난, 여기 [ 사랑의 불시착 OST Part 4 ] - 백예린
#  90위: 안녕과 안녕으로 [ 안녕과 안녕으로 ] - 이예준
#  91위: Underwater [ Delight - The 2nd Mini Album ] - 백현 (BAEKHYUN)
#  92위: Birthday [ Birthday ] - Anne-Marie
#  93위: 영웅 (英雄; Kick It) [ NCT #127 Neo Zone - The 2nd Album ] - NCT 127
#  94위: Interlude : Shadow [ MAP OF THE SOUL : 7 ] - 방탄소년단
#  95위: Yours (Feat. 이하이, 창모) [ Yours (Feat. 이하이, 창모) ] - Raiden, 찬열 (CHANYEOL)
#  96위: 사랑, 하자 [ 자화상 - The 1st Mini Album ] - 수호 (SUHO)
#  97위: Outro : Ego [ MAP OF THE SOUL : 7 ] - 방탄소년단
#  98위: Square (2017) [ Every letter I sent you. ] - 백예린
#  99위: 니가 왜 거기서 나와 (Narr. 고은아) [ 니가 왜 거기서 나와 ] - 영탁
# 100위: 포장마차 [ 포장마차 ] - 황인욱

# %%
import requests
from bs4 import BeautifulSoup
 
if __name__ == "__main__":
    RANK = 100 ## 멜론 차트 순위가 1 ~ 100위까지 있음
 
    header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}
    req = requests.get('https://www.melon.com/chart/week/index.htm', headers = header) ## 주간 차트를 크롤링 할 것임
    html = req.text
    parse = BeautifulSoup(html, 'html.parser')
 
    ranking = soup.find_all('td', {'class': 'wrap t_center'})
    titles = parse.find_all("div", {"class": "ellipsis rank01"}) 
    singers = parse.find_all("div", {"class": "ellipsis rank02"}) 
    albums = parse.find_all("div",{"class": "ellipsis rank03"})
 
    title = []
    singer = []
    album = []
 
    for i in range(0, len(ran))
